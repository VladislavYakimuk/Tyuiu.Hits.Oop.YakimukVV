// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания №24

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс Notification в C#, который будет представлять уведомления
// пользователям. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу Notification:
// • Атрибуты: ID уведомления (NotificationId), Текст уведомления (MessageText),
// Тип уведомления (Type).
// • Методы:
// o DisplayNotification(): метод для отображения уведомления
// пользователю.
// o SendNotification(): метод для отправки уведомления.
// o GetNotificationDetails(): метод для получения деталей уведомления.
//
// Требования к производным классам:
// 1. EmailУведомление (EmailNotification): Должно содержать дополнительные
// атрибуты, такие как Адрес электронной почты (EmailAddress).
// Метод SendNotification() должен быть переопределен для отправки
// уведомления по электронной почте.
// 2. SMSУведомление (SMSNotification): Должно содержать дополнительные
// атрибуты, такие как Номер телефона (PhoneNumber).
// Метод SendNotification() должен быть переопределен для отправки
// уведомления через SMS.
// 3. PushУведомление (PushNotification) (если требуется третий класс): Должно
// содержать дополнительные атрибуты, такие как Платформа (Platform,
// например, iOS или Android). Метод DisplayNotification() должен быть
// переопределен для отображения уведомления на мобильной платформе.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
// Базовый класс Notification
public class Notification
{
    public int NotificationId { get; set; }
    public string MessageText { get; set; }
    public string Type { get; set; }

    public Notification() { }

    public Notification(int notificationId, string messageText, string type)
    {
        NotificationId = notificationId;
        MessageText = messageText;
        Type = type;
    }

    public virtual void DisplayNotification()
    {
        Console.WriteLine($"[Уведомление] {MessageText}");
    }

    public virtual void SendNotification()
    {
        Console.WriteLine("Уведомление отправлено.");
    }

    public virtual string GetNotificationDetails()
    {
        return $"ID: {NotificationId}, Тип: {Type}, Текст: {MessageText}";
    }
}

// EmailNotification
public class EmailNotification : Notification
{
    public string EmailAddress { get; set; }

    public EmailNotification() { }

    public EmailNotification(int notificationId, string messageText, string emailAddress)
        : base(notificationId, messageText, "Email")
    {
        EmailAddress = emailAddress;
    }

    public override void SendNotification()
    {
        Console.WriteLine($"Email отправлен на {EmailAddress}: {MessageText}");
    }

    public override string GetNotificationDetails()
    {
        return base.GetNotificationDetails() + $", Email: {EmailAddress}";
    }

    // Взаимодействие: переслать уведомление другому EmailNotification
    public void ForwardTo(EmailNotification other)
    {
        other.MessageText = this.MessageText;
        Console.WriteLine($"Уведомление переслано с {EmailAddress} на {other.EmailAddress}");
    }
}

// SMSNotification
public class SMSNotification : Notification
{
    public string PhoneNumber { get; set; }

    public SMSNotification() { }

    public SMSNotification(int notificationId, string messageText, string phoneNumber)
        : base(notificationId, messageText, "SMS")
    {
        PhoneNumber = phoneNumber;
    }

    public override void SendNotification()
    {
        Console.WriteLine($"SMS отправлено на {PhoneNumber}: {MessageText}");
    }

    public override string GetNotificationDetails()
    {
        return base.GetNotificationDetails() + $", Телефон: {PhoneNumber}";
    }

    // Взаимодействие: отправить копию уведомления другому SMSNotification
    public void CopyTo(SMSNotification other)
    {
        other.MessageText = this.MessageText;
        Console.WriteLine($"SMS уведомление скопировано с {PhoneNumber} на {other.PhoneNumber}");
    }
}

// PushNotification
public class PushNotification : Notification
{
    public string Platform { get; set; }

    public PushNotification() { }

    public PushNotification(int notificationId, string messageText, string platform)
        : base(notificationId, messageText, "Push")
    {
        Platform = platform;
    }

    public override void DisplayNotification()
    {
        Console.WriteLine($"Push на {Platform}: {MessageText}");
    }

    public override string GetNotificationDetails()
    {
        return base.GetNotificationDetails() + $", Платформа: {Platform}";
    }

    // Взаимодействие: синхронизировать уведомление между платформами
    public void SyncWith(PushNotification other)
    {
        other.MessageText = this.MessageText;
        Console.WriteLine($"Push уведомление синхронизировано между {Platform} и {other.Platform}");
    }
}

// Пример использования с конструкторами и взаимодействием:
var email1 = new EmailNotification(1, "Проверьте вашу почту!", "user@example.com");
var email2 = new EmailNotification(4, "Вторая почта", "admin@example.com");
email1.DisplayNotification();
email1.SendNotification();
Console.WriteLine(email1.GetNotificationDetails());
email1.ForwardTo(email2);

var sms1 = new SMSNotification(2, "Ваш код: 1234", "+79991234567");
var sms2 = new SMSNotification(5, "Второй номер", "+78889997766");
sms1.DisplayNotification();
sms1.SendNotification();
Console.WriteLine(sms1.GetNotificationDetails());
sms1.CopyTo(sms2);

var push1 = new PushNotification(3, "Новое обновление доступно!", "Android");
var push2 = new PushNotification(6, "Для iOS", "iOS");
push1.DisplayNotification();
push1.SendNotification();
Console.WriteLine(push1.GetNotificationDetails());
push1.SyncWith(push2);
// Out:
// [Уведомление] Проверьте вашу почту!
// Email отправлен на user@example.com: Проверьте вашу почту!
// ID: 1, Тип: Email, Текст: Проверьте вашу почту!, Email: user@example.com
// Уведомление переслано с user@example.com на admin@example.com
// [Уведомление] Ваш код: 1234
// SMS отправлено на +79991234567: Ваш код: 1234
// ID: 2, Тип: SMS, Текст: Ваш код: 1234, Телефон: +79991234567
// SMS уведомление скопировано с +79991234567 на +78889997766
// Push на Android: Новое обновление доступно!
// Уведомление отправлено.
// ID: 3, Тип: Push, Текст: Новое обновление доступно!, Платформа: Android
// Push уведомление синхронизировано между Android и iOS
